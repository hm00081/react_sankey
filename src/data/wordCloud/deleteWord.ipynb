# %%
import nltk
nltk.download(stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hm000\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords 

print(stopwords.words(english))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
Target = "사람(정치인), 장소(기관) 장소(금융기관_은행)	장소(금융기관_은행)	장소(금융기관_은행)	서비스(호텔 서비스)	사고, 서비스	서비스(영상물), 사람(영상물 속 주인공, 출연진)	서비스(신문기사, 저널)	제품(전자기기-iphone, samsung galaxy7) 장소(도시-vancouver, LA)	제품(전자기기-bose headphone,GPS, TV), 서비스(영화-인터스텔라)		사람(도널드 트럼프-carnival barker)				사건(분열의 원인이되는 사건_tv토론)	사건(2012 US presidential election)	서비스(정치인과 관련된 뉴스포스팅 서비스)		심리(Weibo에서 언급된 주제에 대한 Root user의 심리), 사고(Weibo에서 언급된 주제에 대한 Root user의 사고)		사건: 소셜 현상이나 real world 관련된 사건이 소셜 미디어에서 hashtags나 keyword와 함께 나타난 것(ex.김정남 암살 사건)	사건(트윗 사용자들의 언급 대상이 되는 Topic) 사고(리트윗의 대상이 되는 오리지널 트윗)			심리(의견보유자가 작성한 글에 대한 심리), 사고(의견 보유자가 작성한 글에 대한 사고), 사건(어디에서, 무슨일이, 누구와 관련되어 일어났는지)		사고(리트윗의 대상이 되는 오리지널 트윗)	사고(개인이 남기는 initial Post)	제품, 서비스			사고, 심리, 사건(리트윗 확산에 영향을 주는 오리지널 트윗)		사건(2010 칠레 대지진, parking day)	사건(2014 브라질 월드컵 개막전 경기)	사람, 서비스, 장소, 사건, 제품,사고, 심리(Here, a target can be anything of interest: a person, a brand, a company, a location, anevent, or even something abstract such as a concept or an idea—as long as it can be defined by a set of keywords)		행동, 장소: 특정 장소로 이동하는 유저들의 행동, 장소 및 행동, 시점 등이 검색 키워드가 됨		사건(트윗에서 일어난 여러 사건들_해시테그가 달리는 대상 사건들)		사람, 행동, 심리, 장소, 사고, 서비스, 제품, 사건(Google+에 URL로 공유되어 사용자가 자신의 의견을 업로드한 포스트)		사건(마이크로 블로그에서 다루어지는 특정 사건-Guo MeiMei...)	장소(트윗이 발생한 장소)	서비스, 제품			사건(럭비경기, 호주대선 등.. 트윗에서 다루고 있는 주요 사건)	사건(2012 미국대선)	서비스(24/7 news channels-USA/Asia-비디오 및 오디오자료 포함)	서비스(reddit에서 제공되는 뉴스 기사)			서비스(프랑스 Poll TV Program)	서비스(소셜 TV 서비스 - 프로그램이 상영될 때 실시간으로 댓글 정보가 달리는 것)		사건: 텍스트 데이터에서 논쟁의 주제가 되는 사건(ex. 학교폭력(School Bullying))		사람: 사람의 성격		제품 : 음식	제품: 아마존에서 판매하고있는 5가지 제품	사람: 기사와 관련된 인물 0 장소 : 기사에 나타난 장소 제품 : 기사에 나타난 제품 복합속성(전자기기 및 영화에 대한 다양한 속성-전자기기:음악, 모델, 사운드 영화-스토리, 등장인물) 파생속성(대상과 관련은 없지만 연상될 수 있는 속성 예시: 등장인물의 악세사리, 전자기기 관련 회사의 이미지 모델)		복합속성: 트럼프와 관련된 여러 세부 속성 키워드 주제들(주제와 관련된 키워드를 여러 속성으로 나타냄)	복합속성: 대선토론에서 다루어진 주제들	복합속성: 대선후보 트윗에서 다루어진 키워드들			복합속성: 900명의 오피니언 리더들이 대선 이슈에 대해서 의견을 남긴 Topic들 (Defence, Election, Economy, Welface, Horse race)																				복합속성: 다양한 특정 Target에서 추출되는 Markers							복합속성(제품안에 포함된 다양한 기능, 외형 등을 다룸)															복합속성: 한 사건에 대한 다양한 주제의 의견		복합속성: MBTI의 각 16개의 성격 유형이 39개의 대표 어휘로 나눠지고, 이 대표어들은 161개의 성격어휘로 나눠짐.						평가(정치인에 대한 평가의견)	평가(은행 이용 만족도에 대한 평가)	평가(은행 이용 만족도에 대한 평가)	평가(은행 이용 만족도에 대한 평가)	의견, 평가(호텔 서비스에 대한 의견 및 평가(online review))	의견 및 평가: 브랜드에 대한 사용자의 의견, 평가 입장: 기업의 공식발표	의견/평가(영상물 속 장면에 대한 의견 및 평가 댓글)	평가(신문기사에 대한 코멘트)	감정(제품이나 도시에 대해 갖는 사용자들의 감정)	의견/평가(제품 및 서비스에 대한 리뷰)		의견(트럼프에 대한 코멘트)	의견(대선 후보들의 정책-공략), 입장(상대 후보에 대한 의견)	의견(대선 후보들의 정책-공략), 평가(대선 후보 트윗에 대한 사용자의 평가 ex. like)	의견: 각 정당을 지지하는 트윗 유저(각 정당의 의원들)의 의견	의견 및 감정: 두 커뮤니티(오바마를 지지하는 커뮤니티, 롬니를 지지하는 커뮤니티)의 트윗 중 분열(Divergence)과 관련된 의견이나 감정표현	의견 및 입장(각 주제에 대해서 오바마, 롬니, 대선 등의 키워드가 언급된 트윗들을 수집)			의견: Comments 리포스팅 된 Weibo에 대한 사용자의 의견	태도: 비슷한 behaviors를 가진 Weibo 사용자	의견: Weibo 사용자들이 토론하는 사건 자체나 사건과 관련된 주제에 관한 의견(what people discuss can be about the event itself, or other topics derived from the event)	의견(특정 사건에 대한 사용자의 의견)	감정(취임식 중 역대 대통령들의 감정)		의견(한 사건에 대한 다른 사람들의 의견)	감정: 트윗에 드러난 한 사용자의 감정(emotional style)	의견, 평가, 입장, 감정: 오리지널 트윗에 대해 남기는 리트윗의 의견, 평가, 입장, 감정	의견, 평가, 태도, 감정(initial post message에 대한 댓글)	의견, 평가: 제품이나 서비스 리뷰에 들어간 사용자의 의견이나 평가	감정: 블로그에서 수집되는 감정 정보		의견, 감정(오리지널 트윗에 대한 의견 및 감정)		의견 및 감정(주어진 사건(칠레 대지진, parking day)에 대해 트위터 사용자들이 남기는 의견 및 감정)	의견 및 평가(월드컵 개막전 경기에 대한 트윗)	입장(대상에 대한 글 작성자의 입장), 감정, 의견(입장안에 감정과 의견이 포함됨)		의견:트윗유저가 하루 일과중 남긴 텍스트		의견(reasontobe, reasonwhy등의 해시테그)		의견(Google+에 올라온 사진에 대한 의견), 평가(Google+에 올라온 사진에 대한 평가), 태도(Google+에 올라온 사진에 대한 태도), 감정(Google+에 올라온 사진에 대한 감정)	의견(제품에 대한 사람들의 의견)	의견(특정 대상 사건에 대해 남겨지는 블로그포스팅 글)	의견(각 장소에서 발생하는(그 지역과 관련된) 트윗 메시지)	감정(대상에 대해 느끼는 감정)	평가, 태도, 감정(대상에 대한 UX 경험과 관련된 평가, 태도(표정), 감정)	의견(트윗에서 추출되는 여러 사용자들의 의견 - PRISM 데이터, 마이크로소프트에 대한 사람들의 의견)	감정(시간별로 기록되는 감정어휘들)	의견(트윗에서 정치적으로 경쟁하거나 협력에 관해서 언급한 문장과 키워드)	입장, 태도 (뉴스에서 전하는 다양한 소식, 저널리즘의 태도-캡션)	평가(독자들이 reddit에서 다루어지는 기사 내용이 루머인지 아닌지를 판단함)	의견(팀 회의 메시지)		의견(투표 프로그램을 본 시청자들이 남긴 트윗 텍스트, 해시테그)	의견(TV 프로그램을 본 시청자들이 남기는 트윗 텍스트)		의견(주제에 대해 사람들이 남긴 텍스트)		평가: MBTI 성격 유형에서 사람의 성격을 묘사하는 데에 사용한 형용사		의견, 평가, 입장, 태도, 감정: 식품 시스템안에서 나타나는 사람들의 의견, 평가, 입장, 태도, 감정 (the voice of peoeple in food system)	평가: 5가지 제품에 대한 리뷰	의견 : 뉴스에 나타난 개체에 대한 의견	감정: 각 유저들이 가지고 있는 감정의 극성 비중	의견, 입장: 회의 데이터에서 각 발화자가 낸 메시지 글 작성자(주체): 평가를 남긴 사람	글 작성자(주체): 평가를 남긴 사람	글 작성자(주체): 평가를 남긴 사람	글 작성자(호텔 리뷰를 남기는 사람)	단체, 일반인 (브랜드 유저 / 직원 / 기업)		키 플레이어(유명인), 단체 일반인: 신문기사에 대해 코멘트를 남기는 주체	글 작성자(주체)	글 작성자(주체):대상에 대해 리뷰를 남긴 사람들			키 플레이어(오바마, 롬니와 같은 토론의 패널), 일반인(토론진행자, 일반 토론 참가자) - 교수님 코멘트: 추후 키 플레이어의 정의를 각주에 넣도록 하자. 네트워크 개념의 키 플레이어와 다르다는 것을	키 플레이어(도널드 트럼프, 힐러리 클린턴)	글 작성자: 114대 미국 의회 의원들(민주당, 공화당 의원)	키플레이어(커뮤니티에서 중요한 비중을 차지하며 트윗을 남기는 키플레이어 유저 그룹)	글작성자(주체)(Grassroot), 키플레이어(Political Figures), 단체(Media)	키 플레이어(유명인): 미국 대선 후보 및 정치인, 단체(미국정당-공화당, 민주당)		글 작성자: Root user(원본 Weibo를 작성한 Weibo 사용자)  키플레이어: Root weibo를 많이 리포스팅 한 사용자	글 작성자(주체): Weibo 작성자 커뮤니티	글 작성자(주체): Weibo 작성자	글작성자(Tweet users)	키플레이어(역대 대통령)		단체(Group - A group label that uniquely identifies the event-group to which the event belongs./사건이 속한 그룹을 보여주기 위한 라벨), 일반인	글 작성자: 트윗 사용자(PEARL collects all the tweets of that person.)	글 작성자(주체): 리트윗을 남기는 개인	글 작성자(주체): 포스트를 남기는 사람, 댓글을 다는 사람	글 작성자(주체): 리뷰 작성자	글 작성자(주체): 블로그에서 감정 정보를 남기는 사람		단체(방송사, 언론, 기관), 키 플레이어(유명인), 일반인		글 작성자(주체): 트위터 사용자		글작성자(주체) : 온라인 미디어에서 대상에 대한 글을 작성한 주체		글 작성자(주체): 트위터 사용자		글 작성자 (reasontobe, reasonwhy에 대한 해시테그를 남기는 트윗 유저)		글작성자(주체): URL을 공유하고comment를 추가한 주체				글 작성자(주체)	일반인(UX 경험을 체험하는 대상자)	글 작성자(주체)(트윗을 남기는 사용자들)		키플레이어(유명인): topic leaders					글 작성자(주체): 트윗 사용자	글 작성자(주체): 트윗 사용자		글 작성자(주체) : 텍스트 데이터를 작성한 사람				글 작성자: 식품 시스템과 연관 있는 사람들 (ex, food bank users, famer)	글 작성자(주체): 리뷰를 작성한 작성자		커뮤니티: 소셜 미디어 속 네트워크를 이루는 커뮤니티 유저들	커뮤니티: 회의에서 메시지를 주고받는 사람들 시작/소멸(정치인의 회사 부임 기간)	축적(기간별로 평가 내용이 축적되어 표현됨)	연속성(시간의 진행에 따른 감성 극성의 추이를 파악)	축적(기간별로 평가 내용이 축적되어 표현됨) 최고점/최저점(가장 많이 의견이 축적된 부분과 그렇지 않은 부분을 표현하고자 함)	축적(댓글이 남겨지는 패턴을 연도별로 축적해서 나타냄)		성장/축소(영상물 장면의 구간마다 수집되는 의견의 수에 따라 성장과 축소가 나타남) 연속성(각 장면 흐름에 따른 사용자의 의견 변화를 연속적으로 나타내고자 함) 축적(수집되는 의견들이 시간에 따라 쌓이는 부분을 나타내고자 함)	축적(시간이 지남에 따라 대상 기사에 대한 코멘트가 점점 늘어나면서 쌓임) 성장/축소(의견의 확산에 따른 코멘트 양의 성장 축소를 나타내고자 함)		시작/소멸: 각각의 측면에서 나타나는 논쟁의 시작 및 논쟁의 소멸 시간을 나타냄			축적(발화자들의 의견이 시간에 따라 축적됨)	축적(발화자들의 의견이 시간에 따라 축적됨)	시작/소멸(시간별로 등장하는 키워드의 시작과 소멸을 나타내고자 함) 연속성(시간에 따라 등장하는 키워드의 지속정도를 나타내고자 함)	축적(오바마-롬니 대선토론에서 시간에 따라 기록되는 토론의 주제)	연속성(각 Topic에 대해서 대선이 진행되는 기간동안 수집된 트윗의 빈도수 변화를 연속적으로 나타내고자 함) 시작/소멸(관련 topic에 카운팅되는 키워드가 시작되거나 소멸되는 시점을 나타내고자 함) 성장/축소(수집된 키워드의 빈도에 따라서 의견 양의 성장 및 축소를 나타냄)	축적(시간별로 축적되는 포스팅 주제의 패턴을 나타내고자 함)		축적: 시간에 따른 Weibo 확산 과정 구조를 나타냄 성장/축소, 반복: 오리지널 웨이보의 리포스팅 패턴의 성장과 축소, 반복 패턴을 나타냄	시작과 소멸: Weibo가 리포스팅이 시작되고 멈추는 과정 연속성: Weibo가 리포스팅 되는 과정  축적: 시간에 따른 Weibo 의 축적 반복: 리포스팅이 반복되는 과정	연속성: 한 사건이 발생하고 나서 포스팅 되는 Weibo를 나타냄.  성장/축소: 한 키워드가 Weibo에서 언급되는 횟수에 따라 성장과 축소를 나타냄  시작/소멸: 시간에 따라 키워드의 시작과 소멸을 나타냄	시작/소멸: Topic을 공유하는 군집(키워드)의 생성 및 소멸 성장/축소: 등장하는 키워드의 언급 빈도에 따라서 성장과 축소를 시간에 따라 나타냄	시작/소멸: 취임사의 시작과 끝		시작/소멸:첫번째 이벤트와 마지막 이벤트 (timeline stretching between the first of the events shown and the last.) 연속성: 타임라인에 따라 각 이벤트에 관여한 참가자들을 보여줌( We then loop over all events that share these participants in order of appearance on the timeline) 성장/축소: 클라이맥스 이벤트를 중심으로 버블의 크기가 커지고 작아짐. (A climax event together with all bridged events approximate a story, where we expect events to increase in bubble size when getting closer to the climax event (the biggest bubble in a row) and then gradually decrease after the climax event.) 성장/축소: 시간에 따른 사용자의 부정/긍정 감정 변화를 나타냄	연속성: 리트윗이 남겨지는 시간의 연속성 최고점/최저점: 트윗 활동을 하는 시간동안 anomalous한 행동 패턴을 보이는 지점	성장/축소: 시간에 따라 기록되는 포스팅 활동의 활발한 정도에 따른 성장/축소를 나타냄. 연속성: initial post- replies의 등장관계를 연속적으로 나타냄		연속성: sentiments expressed by an individual blogger about specific topics over time		시작/소멸(리트윗 활동이 시작되고 종료되는 기간을 표현), 성장/축소(리트윗의 확산과정을 시간에 따라 나타내고자 함)		성장/축소: 시간에 따라서 특정 사건에 대해 언급한 빈도수 변화 성장/축소: 시간별로 기록되는 Marker 빈도수의 성장 또는 축소 축적: 각 문서별로 표시되는 Marker의 축적 정도		연속성 및 축적: 시간별로 수집되는 사용자들의 행동 및 장소 등을 표현		시작/소멸, 반복, 가속(트윗을 남기는 기간 및 시간의 시작, 소멸 과정, 리트윗의 반복과정, 시계열 분석의 가속 과정을 나타냄)		시작/소멸: Google+ 포스트의 공유의 시작과 소멸이 나타남 연속성 : 한 Google+에 공유된 포스트가 공유가 되는 과정을 연속적으로 나타냄.		연속성(블로그 포스팅의 극성 성향의 변화)	연속성(각 지역의 트윗 발생 빈도를 시간에 따라 연속적으로 나타내고자 함)	연속성(감정의 변화를 시간에 따라 연속적으로 나타내고자 함)	시작/소멸(감정 정보가 시작해서 소멸하기까지의 시간을 표현하고자 함)	성장/축소(특정 극성을 나타내는 트윗 의견들의 확산 과정을 표현하는 시간)	축적(여러 종류의 감정어휘들이 기록되는 시간이 축적되어 나타남)	연속성: 시간에 따라 전개되는 coopetition의 흐름을 나타내고자 함	연속성: news의 토픽의 흐름을 나타내기 위해 표현되는 기간의 연속성	연속성(루머의 빈도 흐름을 나타내기 위해 news를 수집한 기간)			축적(TV쇼가 진행되는 동안 트윗이 축적되는 것을 표현)	축적(TV쇼가 진행되는 동안 트윗이 축적되는 것을 표현)									축적: 두 유저 간의 감정 관계의 변화를 나타내는 시간들을 축적시킴	연속성: 회의가 진행되는 기간을 년도, 월, 시간 등으로 세분화하여 표현 축적: 다양한 메시지들이 동시다발적으로 축적되는 것을 표현"

# %%
Target.strip()
# Out:
# '사람(정치인), 장소(기관) 장소(금융기관_은행)\t장소(금융기관_은행)\t장소(금융기관_은행)\t서비스(호텔 서비스)\t사고, 서비스\t서비스(영상물), 사람(영상물 속 주인공, 출연진)\t서비스(신문기사, 저널)\t제품(전자기기-iphone, samsung galaxy7) 장소(도시-vancouver, LA)\t제품(전자기기-bose headphone,GPS, TV), 서비스(영화-인터스텔라)\t\t사람(도널드 트럼프-carnival barker)\t\t\t\t사건(분열의 원인이되는 사건_tv토론)\t사건(2012 US presidential election)\t서비스(정치인과 관련된 뉴스포스팅 서비스)\t\t심리(Weibo에서 언급된 주제에 대한 Root user의 심리), 사고(Weibo에서 언급된 주제에 대한 Root user의 사고)\t\t사건: 소셜 현상이나 real world 관련된 사건이 소셜 미디어에서 hashtags나 keyword와 함께 나타난 것(ex.김정남 암살 사건)\t사건(트윗 사용자들의 언급 대상이 되는 Topic) 사고(리트윗의 대상이 되는 오리지널 트윗)\t\t\t심리(의견보유자가 작성한 글에 대한 심리), 사고(의견 보유자가 작성한 글에 대한 사고), 사건(어디에서, 무슨일이, 누구와 관련되어 일어났는지)\t\t사고(리트윗의 대상이 되는 오리지널 트윗)\t사고(개인이 남기는 initial Post)\t제품, 서비스\t\t\t사고, 심리, 사건(리트윗 확산에 영향을 주는 오리지널 트윗)\t\t사건(2010 칠레 대지진, parking day)\t사건(2014 브라질 월드컵 개막전 경기)\t사람, 서비스, 장소, 사건, 제품,사고, 심리(Here, a target can be anything of interest: a person, a brand, a company, a location, anevent, or even something abstract such as a concept or an idea—as long as 
# ...

# %%
Intermediation = "대상에 대해 나타나는 감정이 무슨 의미(원인)을 가지고 있는지를 탐자히고자 함 의견을 덩쿨의 계층 구조를 통해 나타내어 해당 감정을 이끌어낸 원인을 찾음.															의견보유자가 남긴 텍스트 데이터의 감성 정보 의도 파악.				사용자가 남긴 리뷰에서 나타나는 의도를 파악하고자 함																																																																호텔을 평가했을 때 해당 평가를 왜 내렸는지에 대한 정보를 나타내고자 함											커뮤니티 간 논쟁의 분열(Divergence)을 일으키는 주요 키워드를 탐지함						각 시간대 별로 나타나는 키워드(증거자료)들을 통해 주제 변화 탐지 (Detecting and presenting themes in different time periods) 포스팅/리포스팅 메시지(증거자료)를 통해 weibo 사용자의 행동패턴 확인					감성 분석의 증거가 되는 데이터를 제공. Providing data evidence for analytical reasoning.			key phrases 를 탐색하여 해당 리뷰의 중심이 되는 문장을 탐지하고자 함													포스트 확산의 원인이 되는 공유/재공유 활동을 탐지함.									news에서 자주 돋보이는 토픽 흐름에 영향을 주는 증거(토픽과 관련된 이벤트, 사람, 위치, 시간)를 정리하고자 함							덩쿨의 성장과정을 통해 감성 패턴의 주제를 탐지 할 수 있음. 		각 대상에 대해서 상반된 의견 및 평가를 감지하고자 함			각 토론자 및 의견에 대해서 논쟁 패턴을 감지해야함	각 토론자 및 의견에 대해서 논쟁 패턴을 감지해야함			대선기간동안 글을 남기는 글 작성자, 미디어, 정치인들의 논쟁 이슈를 감지하고자 함																																																									특정 대상이나 서비스에서 나타나는 다양한 복합속성 및 파생속성을 다루고자 함		트럼프(사람)와 관련된 다양한 키워드(양상:복합속성)를 분석	토론에서 다루는 여러 주제들을 모두 시각화하여 분석하는 것이 필요함	트윗에서 다루는 여러 주제들을 모두 시각화하여 분석하는 것이 필요함			대선기간동안 다루는 여러 Topic별로 수집되는 트윗 의견을 시각화하고자 함													한 제품에 대해 여러 사용자가 남긴 리뷰를 다양한 관점(Keywords)에서 분석하여 인사이트를 제공하고자 함							여러 taget(ex hobbit, coca cola 등)에 대해서 다양한 속성을 가지는 stance markers(ex joy, great, like)를 시각화하고자 함							제품에 포함된 다양한 속성에 대한 의견을 감지함															한 가지 사건에 대한 다양한 관점의 의견을 감지함. 각 관점은 덩쿨의 줄기를 통해 나타남.		성격 대표 어휘별 나타나는 세분화된 감정어휘의 양상을 지하철 노선도 재현물을 통해 확인이 가능함.													제공되는 뉴스 및 뉴스에 대한 다수의 평가 정보가 루머인지의 여부를 분석하고자 함		각 장면마다 수집되는 의견을 키워드 형태로 요약하고자 함							후보가 남긴 키워드 중 중요한 내용만 정리하여 제시	트윗으로 남겨진 의견들을 다양한 관점에서 요약하고자 함								동일한 Topic을 이야기하는 트윗 유저들의 의견을 요약하여 정리하고자 함					각 개인이 남긴 트윗 내용을 요약하고자 함							트윗 문장에서 대상이되는 사건과 관련된 의견을 요약하고자 함 	2014 브라질 월드컵 개막전 경기와 관련된 트윗 문장에서 자주 나타나는 키워드, 그 키워드와 연결된 문맥을 요약하고자 함			트윗을 남긴 사용자의 행동 관련 의견을 요약하고자 함		해시테그가 포함된 의견들을 요약하고자 함					각 지역에서 발생한 트윗의 내용을 요약하고자 함			트윗 텍스트의 극성 및 키워드 정보를 요약하고자 함		2012년 대선과 관련된 정치적 협력 및 분쟁에 대한 키워드를 요약하고자 함					Poll TV Show에서 다루어지는 다양한 트윗 텍스트를 키워드(태그) 별로 요약하고자 함								5가지 제품에 대한 글 작성자의 의견을 요약하여 한 시각화에 나타내고자 함.	다양한 기사에 나타난 의견을 요약하여 시각화하고자함									다양한 수준에서 브랜드 퍼스털리티의 내용을 묘사하고자 함						도널드트럼프와 관련된 인물, 사건 등 다양한 수준에서 감성 정보를 묘사하고자 함					대선기간동안 다루는 여러 Topic별로 수집되는 트윗 의견을 시각화하고자 함	각 정당 또는 각 후보에 대한 뉴스의 견해를 다양한 수준에서 탐색하고자 함									사용자(개인)의 감정을 다양한 수준과 관점에서 요약함. (Summarizing personal emotions at multiple levels and from multiple perspectives.)			다양한 관점에서 의견을 시각적으로 요약하여 다양한 수준으로 감성정보를 묘사하고자 함.					사람들이 주고받는 트윗 내용 중, 토픽, 키워드, 이모티콘과 같은 여러 측면을 다양한 수준에서 수집하여 시각화하고자 함		stance markers(ex joy, great, like)를 통해 감성 정보를 다양한 수준으로 묘사하고자함.																													모든 유저들간의 감정 관계를 다양한 수준에서 보여주고자 함	회의에서 수집되는 다양한 대화내용들을 기간, 인물, 극성 측면으로 다양하게 묘사하고자 함							대상에 대해 느껴지는 감정을 종류별로 분류하고 시각화하고자 함													토론 테마와 리포스팅 관계 속에서 유사한 메시지를 그룹화하여 분류하고자 함		취임사에서 나타난 대통령들의 감정을 탐지하고 분류함(기쁨/놀람/두려움/화남/슬픔)						리뷰에 드러난 작성자의 제품이나 서비스에대한 의견이나 감정을 분석.	블로그에서 나타난 감정 정보를 분류하고자 함						온라인 미디어에서 작성된 텍스트 데이터에서 글 작성자의 감정을 탐지하고 분류.										대상에 대해 느끼는 감정을 정리하고 분류하고자 함	웹 대상에 대한 사용자 경험 중 나타나는 감정을 감지하고자함															음식과 관련된 경험담에서 글 작성자가 느낀 감정을 탐지하고 이를 카테고리화 함.		뉴스 텍스트 데이터에서 나타나는 의견을 통해 감정을 탐지하고 이를 분류함. 									은행 기관에 대한 평가 내용의 극성을 시각화에 나타내고자 함	은행 기관에 대한 평가 내용의 극성을 시각화에 나타내고자 함	은행 기관에 대한 평가 내용의 극성을 시각화에 나타내고자 함			영상에 대한 사람들의 반응을 극성별로 분류하고자 함			각 측면에서 나타나는 리뷰의 극성을 정리하고자 함								각 정치인, 정당에 대한 신문기사의 전반적인 극성을 분류하고자 함						역대 대통령의 취임식 연설문에서 나타나는 대통령의 감성의 극성을 분류하고자 함.																				제품의 각 측면에 대한 극성정보를 분류함	블로그 포스팅 안에 추출되는 의견(감성정보)에 대해서 어느 극성을 나타내는 지 분류하고자 함			감성의 극성을 분류하고자 함		감정 데이터의 극성을 다양하게 분류하고자 함									글 작성자의 의견 데이터에서 극성을 분류하여 나타내고자 함. 이는 잎의 색을 다르게 하여 나타냄. (주제가 School Bullying인 경우)					추출한 리뷰에서 나타나는 제품에 대한 글 작성자의 의견이 긍정적인지, 부정적인지를 탐지하고, 분류하여 시각화하고자함. 	뉴스 텍스트 데이터에서 나타나는 의견 속에서 감정의 극성(긍정적/부정적)을 탐지하고, 이를 점수화함. 									 각 개인이 남긴 평가 내용의 극성을 시각화에 나타내고자 함		각 개인이 남긴 평가 내용의 극성을 시각화에 나타내고자 함																				역대 대통령 개개인의 취임식 연설에서 표출되는 감정을 분석하고자 함.			소셜 미디어 사용자의 감성 정보를 파악하여 해당 사용자가 어떤 감성 패턴(emotional style)을 나타내는지 알아볼 수 있음.	리트윗 활동에서 나타나는 비이상적 패턴을 각 개인별 단위로 감성 분석을 하고자 함	개개인의 포스팅 글의 특성(얼마나 자주 포스팅을 남기는지, 그 포스팅에 대해서 얼마나 많은 사람들이 댓글을 다는지)을 반영하여 감성 분석을 하고자 함		각 개인별 기록된 토픽을 정리하고자 함																	감성 변화 정보를 개인별 단위로 정리하고자 함													MBIT성격 유형과 MBTI에서 다루는 성격 형용사를 이용해 개인의 정서 분류 업무가 가능함. 													중국의 영상 댓글 서비스인 단무(Danmu)데이터의 텍스트를 수집하여 감성 분석을 하고자 함													중국어 사용자가 대다수인 소셜미디어 Weibo 게시물에서 나타나는 의견 정보를 분석하고 처리하는 업무 	중국어 사용자가 대다수이 소셜 미디어 Sina Weibo 게시물에 나타나는 사용자의 의견 정보를 분석하고 처리하는 업무	중국어 사용자가 대다수이 소셜 미디어 Sina Weibo 게시물에 나타나는 사용자의 이벤트에 대한 의견 정보를 분석하고 처리하는 업무																					Google+에 포스트에 나타난 다양한 언어의 의견 정보를 분석하고 처리하고자 함																															사람들끼리 비교한다		각 은행 기관의 평가 내용을 서로 비교하고자 함	각 은행 기관의 평가 내용을 서로 비교하고자 함	호텔 서비스에 대해 남긴 여러 의견들을 서로 비교하고자 함, 댓글을 남긴 사람들도 서로 비교함	의견보유자 및 브랜드의 감성 정보를 비교			같은 topic 주제 안에 있는 서로 다른 대상에 포함된 감정 정보를 비교하고자 함	특정 대상, 특정 측면에 대해서 상반된 두 의견을 서로 비교하고자 함		트럼프와 관련된 코멘트(의견)들을 서로 비교함	양극을 이루는 두 패널의 의견을 비교함(의견보유자를 구별하기 위한 매개도 포함)	두 후보자의 트윗 내용을 서로 비교함	의원들이 남긴 트윗의 키워드를 시간별로/그룹별로 비교하고자 함			서로 다른 두 정당 및 정치인들에 대해 언급한 뉴스기사들을 서로 비교하고자 함										트윗 유저들이 남긴 의견, 평가, 입장, 감정 패턴을 서로 비교하고자 함	서로 다른 유저들의 포스팅활동을 비교하고자 함				서로 다른 리트윗 의견 및 감정의 확산과정을 비교하고자 함, 리트윗을 남긴 그룹을 서로 비교하고자 함			특정 키워드와 연결되어 있는(근접해서 등장하는 키워드)를 비교하고자 함										특정 시간에 발생하는 트윗의 내용을 지역끼리 비교하고자 함				서로 다른 종류의 감정어들의 빈도 수를 비교함, 시간에 따라 분포되는 감정어휘의 분포를 서로 비교함	서로 다른 성향을 가진 (경쟁이 일어나는) 의견보유자들의 트윗 텍스트 키워드를 비교하고자 함		각 뉴스 데이터 토픽에 대해서 카운팅 되는 루머 정보들을 서로 비교하고자 함 동일한 토픽 내에서 사람들이 해당 루머 정보에 대해서 대처하는 평가 방식(루머를 질책함, 루머를 무시함, 루머를 믿고 퍼뜨림)의 양을 서로 비교하고자 함				각 토근별로 수집되는 의견들의 양을 서로 비교하고자 함		덩쿨의 성장에서 감성 패턴을 비교하고자 함.						TextWheel에서 두 키워드 간의 관계가 Keyword Glyph로 연결되어 나타나 두 인스턴스의 의견 정보에 따른 비교가 가능함. 		서로 다른 팀들의 회의내용의 극성, 강도 등을 비교하고자 함							정치인들이 어느 곳에 부임하여 로비활동을 펼치는 지를 알리는 의견의 흐름을 시간에 따라 분석함 (대상에 사람과 의견도 포함)	날짜별로 평가 극성의 변화를 파악하고자 함	날짜별로 평가 극성의 변화를 파악하고자 함	날짜별로 평가 극성의 변화를 파악하고자 함	month, week, day 단위로 남겨지는 댓글의 패턴을 연도별로 축적하여 분석하고자 함		영상이 시작되는 구간 별로 시청자들이 어떤 의견과 평가를 보여주었는 지 시간별로 제시하고, 그 과정에서 영상의 스토리라인을 파악할 수 있도록 함	발행된 신문기사에 대해서 시간에 따라 축적되는 코멘트와 평가를 분석하고자 함		시간별로 기록되는 리뷰 및 논쟁 패턴을 분석하고자 함			시간에 따라 축적되는 코멘트를 분석함	시간에 따라 축적되는 트윗을 분석함	시간에 따른 키워드의 등장 흐름을 나타내어 분석하고자 함	시간에 지남에 따라 두 진영의 커뮤니티의 Divergence(의견이 분열되는 것)가 어떻게 이루어지는 지를 탐색	대선 기간별로 수집되는 각 그룹별, topic별 트윗의 추이를 파악하고자 함	시간별로 기록된 기사에서 어느 정당 및 후보가 많이 언급 되었는 지 패턴을 분석하고자 함		하나의 Weibo의 시간에 따른 확산 과정을 여러 단계로 보여줌, 각각의 단계에서는 다른 리포스팅 태도와 주제, Key player가 드러남.	리포스팅을 통해 퍼져가는 Weibo의 확산과정을 보여줌	Weibo사용자 게시물(weibo)에서 나타나는 한 사건에 대한 Keywords의 시간에 따른 확산 과정을 보여줌	트윗 텍스트 키워드가 언제부터 나타나고 소멸하는 지 그 추이를 파악하고자 함	왼쪽에서 오른쪽으로 취임사를 하는 시간에 흐름에 따른 대통령들의 감정을 나타내고자함		Event-centric view에서 하단의 그래프는 시간별로 그룹화된 이벤트들을 분석하고자 함(This second view in the Storyteller demo shows time ordered sequences of events grouped in different rows.)	사용자의 감정의 변화를 시간의 흐름에 따라 나타냄 (Revealing emotional patterns over time)	시간별로 나타나는 각각의 트위터 유저들의 트윗 활동 패턴을 overview 하고자 함	시간별로 나타나는 initial post-replies 의 패턴을 나타내고자 함		시간에 따른 감정 변화를 나타냄		시간별로 기록되는 리트윗의 확산 패턴을 나타내고자 함		시간에 따라 등장하는 사건 관련 키워드의 빈도수를 시각화하고자 함		한 대상에 대한 의견보유자의 시간의 따른 의견을 분석하고 트렌드를 탐색함.		시간별로 기록되는 행동 패턴을 파악하고자 함		시간별로 남겨지는 대상 해시태그의 분포 변화를 파악하고자 함		시간에 따른 Google + 포스트의 확산과 포스트에 대한 유저의 감정 변화를 탐색함		시간에 따라 변화하는 블로그 글의 극성을 분석하고자 함	시간에 따라 각 장소에서 발생하는 트윗의 패턴을 분석하고자 함	시간에 따라 변화하는 감정의 패턴을 분석하고자 함	시간에 따른 감성 변화를 나타내고자 함	시간에 따라 확산되는 트윗의 양, 극성 변화의 흐름을 분석하고자 함	시간별로 분포되는 감정어휘들의 추이를 분석하고자 함	시간의 연속성에 따라 기록되는 coopetition(경쟁-협력) 패턴의 분열과 화합과정, 그리고 자주발생하는 패턴을 분석하고자 함	시간의 연속성에 따라 기록되는 다양한 뉴스 주제들을 분석하고자 함	시간의 연속성 구간에 따라 변화하는 루머 관련 정보의 변동성을 분석하고자 함				시간별로 수집되는 트윗을 시각화하고자 함										시간에 따른 대화의 축적을 나타내고자 함. 기간 연도에 따라서 메시지의 내용을 연속적으로 표현하고자 함							topic leader들이 분열이 일어나거나 협력이 일어나는 부분을 탐색하여 분석하고자 함																							중요한 의견 찾기: 여러 은행에 걸쳐 공통적으로 나타난 평가 정보 키워드를 찾음				가장 의견이 많이 오고간 중요한 장면(HOT SPOT)을 찾고자 함									커뮤니티 간 논쟁의 분열(Divergence)을 야기하는 인물 찾기				한 weibo의 확산 과정에서 Root Weibo를 작성한 Root user, Root Weibo를 리포스팅에 영향을 많이 끼친 사용자인 Key Player를 찾을 수 있음. 	Understanding reposting feature of key players: 중심 유저와 소셜이벤트를 리포스팅 특징에 따라 분류할 수 있음.			격한 감정이 일어나는 순간, 취임사에서 나타난 대통령의 의견이나 태도를 찾고자 함.		Participation-centric view에서, 각 유저들이 관여한 이벤트를 살펴봄으로서, 어떤 유저가 중요 이벤트에 많이 참여했는지를 알 수 있음.		비이상적인 패턴을 보이는 감성(의견, 입장) 구간, 인물 노드 등을 찾고자 함	특이한 포스팅 패턴을 가지고 있는 사람을 찾고자 함		블로그 텍스트 데이터 중, 비중있게 다루어지는 키워드를 찾고자 함(의견, 감정)		트윗 활동을 진행하는 의견보유자들을 구별시켜서 중요한 활동을 하는 인물(Opinion Leader), 그 인물의 의견이나 감정을 찾고자 함		가장 활발히 활동하는 유저를 랭크하고자 함		특정한 텍스트 문서에서 드러나는 입장(stance)을 찾고자함(stance markers), 여러 개의 텍스트 문서에서 stance marker가 어떻게 드러나는지 알아 보고자함.				중요한 인물 찾기(검색 대상이 되는 해시테그를 가장 많이 남긴 사람을 제시)		특정한 포스트의 확산 과정에서 어떤 인물이 중요한 역할을 하고 있는지 찾고자함.						중요한 극성 변환에 영향을 주는 사용자 그룹을 나타내고자 함			가장 두드러진 뉴스 사건을 찾고자 함							줄기(branch)의 밀집도를 통해 중요한 사건(hot event)이 무엇인지 확인 가능함.															동시적으로 발생하는 여러 포르투갈 정치인들의 로비활동을 쉽게 탐색할 수 있도록 만든다						구간별로 남겨진 댓글을 손쉽게 탐색할 수 있도록 만듦	각 기간별로 코멘트를 남긴 사람이나, 코멘트를 쉽게 탐색할 수 있도록 함	SNS 서비스에서 발견되는 대상에 대한 글 작성자의 다양한 감정을 손쉽게 탐색하고자 하는 감성 시각화를 만들고자 함						상반된 아이디어 집합에 대해 그룹 내/그룹 간 키워드의 등장 관계를 추적하고 탐색하고자 함		대선 기간 중 언급되는 사건이나 인물, 논쟁에 대한 정보를 손쉽게 탐색하고자 함.			다양한 역할과 행동을 가지고 있는 weibo 사용자들을 확인하고 탐색하고자함. Overview 를 제공하여 리포스팅 구조를 탐색할 수 있음.	사용자가 관심있는 소셜 이벤트와 관련된 특정 토픽을 단어들과 함께 제공함으로써 사용자들의 쉬운 탐색과 이해가 가능함. 	이벤트를 요약한 뷰를 의미와 시간적 트렌트와 함께 제공하여 각각의 이벤트를 단계적으로 탐색이 가능함.	다양한 Topic을 안에 포함되는 의견들을 실시간으로 모니터링(탐색)하고자 함			필터링 기능을 이용하여 감성 정보를 손쉽게 탐색 가능(Participation-centric view 일 경우 왼쪽 참여자의 수를 나타내는 바를 클릭하여, Event-centric view 경우 왼쪽 하나의 스토리를 클릭하여 탐색 가능)	시각화로 정리된 감성 정보를 이용하여 각 사용자에 맞는 서비스 제공 가능	여러 트윗 유저들의 활동 중에서, 분석 목적에 맞는 유저나 구간, 의견을 쉽게 탐색할 수 있도록 함		제품이나 서비스에 대한 리뷰를 요약하여 사용자의 손쉬운 탐색을 제공하고자 함			여러 시간 및 여러 위치에서 발생하는 트윗의 흐름을 쉽게 탐색할 수 있도록 함		많은 참가자들이 특정 사건에 대해서 시간별로 남기는 트윗의 추이 및 감성 정보를 손쉽게 파악하고자 함	2014 브라질 월드컵 개막전 경기와 관련된 대량의 트윗 데이터를 토대로 가장 많이 나타나는 키워드들을 구조화하여 그 안에서 나타나는 주요한 내용(정보)을 쉽게 탐색하고자 함	aggregation charts에서 방대한 양의 텍스트 문서에서 사용자가 관심 있는 문서만을 탐색하고자 함.						확산과정을 시각화함으로서 포스트 확산 패턴을 확인하고자 함			시간-장소-의견 의 개념을 손쉽게 탐색할수 있도록 함				여러 시간에 걸쳐서 기록되는 트윗 감정어들을 쉽게 탐색할 수 있는 시스템을 제작하고자 함		각 구간마다 두드러지는 토픽 및 그 토픽과 관련된 뉴스 장면들을 손쉽게 탐색할 수 있도록 함				각 테그별로 수집되는 트윗 정보 및 유저 정보들을 실시간으로 쉽게 탐색할 수 있도록 함			덩쿨을 이용해 계층 구조를 나타내여 한 주제에 대한 사람들의 의견을 손쉽게 탐색하고자 함.				많은 양의 텍스트 데이터를 카테고리별로 시각화함으로서 감성 정보의 손쉬운 탐색이 가능함. 	여러개의 텍스트 데이터를 한 시각화에서 손쉽게 탐색이 가능하게 함. 	방대한 텍스트 데이터를 시각화함으로써 뉴스데이터의 손쉬운 탐색을 가능하게 함. 	소셜 네트워크 속 커뮤니티들의 다양한 감정의 관계를 쉽게 탐색하고자 함	다양한 직책을 가진 사람들이 동시다발적으로 쏟아내는 회의의 메시지들을 쉽게 탐색하고자 함"

# %%
Representation = "동물(곤충), 화합물(거품- 포르투갈 소재 기관)			식물(나뭇잎: 만족도 평가를 나타냄)		순수물질1(화합물(거품): 브랜드)	식물(나무_scene tree): 영상의 장면을 나타내는 나뭇잎과 댓글의 양을 나타내는 줄기 순수물질3(원소-비금속)(토양_ground): 영상이 재생되는 시간 식물(뿌리_root): 각 장면에 대한 사람들의 의견(댓글)	자연경관: 폭포(기사에 대한 여러 의견보유자의 코멘트를 시간별로 퍼뜨리는 형상을 폭포로 표현함)		순수물질1(화합물-거품: 각 대상에서 추출되는 측면 별 논쟁의 주제들을 버블로 나타냄) 식물(나무- 대상이 가지고 있는 모든 측면을 계층적으로 나타냄)		천체(행성을 활용하여 개체, 양상, 의견을 모두 나타냄) 자연경관: 강(River) - 각 후보자들이 특정 날짜에 남긴 트윗의 총량을 나타냄	식물(Stripe Tree)- 그룹 내/ 그룹 간 키워드의 등장 흐름을 나타냄 순수물질1:화합물(Bubble) - 의원들의 트윗 키워드(idea)의 구조를 나타냄	순수물질1(외가닥)- 커뮤니티를 나타냄 순수물질1(화합물: 뉴클레오베이스(핵염기) 쌍)- 두 커뮤니티의 논쟁 이벤트를 보여주기 위해서 두 외가닥 사이를 이어주는 뉴클레오베이스 쌍을 제시함 순수물질1(인산염)- 키플레이어에 해당하는 트윗 유저를 나타냄	식물(Relationship Tree): 각 의견보유자들이 언급한 트윗의 관계를 시간별로 보여주고자 나뭇가지가 뻗어나가는 재현물을 활용함			자연경관: Lake (호수는 강의 발원지 역할을 하며, 호수가 주변 땅에 물을 공급하는 것처럼 키 플레이어는 다른 사용자가 Weibo를 리 포스팅 할 수 있도록 정보를 제공한다.) River: 각 호수(Key pkayer)들을 연결 자연경관 River: Region 사이의 리포스팅 관계를 나타냄.(reposting relations among messages)		동물: 새의 깃털(연설 전체를 하나의 깃털로 표현), 깃털의 가시(대통령이 감정을 크게 표출하는 순간) 		순수물질1(화합물): 거품(Event-centric view)- 참가자	순수물질1:화합물_감성 버블(Emotional Bubble): 사용자에게 자세한 정보를 제공하기 위해 사용됨. 감정의 구성요소를 나타냄.	순수물질1(화합물: 거품): 리트윗 메시지의 패턴을 나타냄	식물(Petal(꽃잎)): 특정 유저가 시간에 따라 오리지널 포스트를 하고, 그에 따른 리플의 패턴을 꽃잎으로 나타냄 식물(Pistil(암술머리, 심피)): 포스팅된 글에 대한 Response를 나타냄(예를 들어 좋아요와 같은 정보라고 보면됨) 식물(줄기): 유저의 포스팅 참가 기간을 나타냄 순수물질1(화합물: 구름): 감정 정보의 자세한 키워드를 구름의 형태로 제시함		식물(해바라기의 구조): 리트윗의 확산 패턴을 보여주기 위해 활용됨 Disc Floret: 트윗 유저가 남긴 텍스트(오리지널 포스트) -topic disc (비활성화된 트윗과, 리트윗에 의해서 활성화된 트윗으로 나뉨) Arrow Seed: 리트윗 텍스트 Ray Floret: 리트윗의 확산과정을 보여줄 수 있는 pathways		자연경관: 강(river)- 이벤트와 관련된 topic의 빈도수를 나타내고자 함	식물(나무): 트윗에서 나타나는 키워드 간의 관계를 나뭇잎과 가지로 표현함. (leaf: 트윗에서 언급되는 키워드, 가지: 서로 관련이 있는 키워드를 연결해주는 링크)	순수물질1 (거품) - Aggregation charts에서 거품은 대상과 관련된 텍스트 문서를 나타냄, 한 개의 거품은 두개의 중첩된 원으로 표현됨.						자연경관: 숲, 원본 포스트에 대한 사용자들의 공유를 전체적으로 보여줌(거시적인 뷰) 식물: 하나의 나무, /Google +에 포스트를 업로드한 사용자에 따른 원본 포스트의 시간적인 확산(미시적인 뷰) 세포(비슷한 의견정보를 군집화하여 세포 형태의 시각화로 나타냄, 각 셀 당 하나의 군집에서 나오는 의견의 극성정보가 포함됨) 여러 양상들이 모여서 하나의 셀을 형성함	순수물질1(ECM: 각 블로그 포스팅을 전자로 표현하고, 극성의 흐름을 원자흐름의 모형으로 나타냄)	자연경관(강-시간에 따라 발생하는 트윗 양의 흐름을 나타내고자 함)	자연경관(강-시간에 따라 발생하는 각 토픽에 대한 감정의 빈도 흐름을 나타냄)		자연경관(강: 특정 대상에 대해서 남겨진 트윗의 극성 변화 및 양의 변화의 흐름을 강으로 은유함)		자연경관(강: 시간에 따른 분열과 협력관계를 강의흐름으로 나타냄)	자연경관(강: 뉴스 토픽들의 빈도를 강으로 표시함)	자연경관(강: 각 토픽에서 추출되는 루머 정보의 양적 변화를 강으로 표시함)			순수물질1(화합물: 거품- 트윗 텍스트 하나를 나타냄)	순수물질1(화합물: 거품- 트윗 텍스트 하나를 나타냄)		식물: 덩쿨(vine): 줄기, 이끼, 가지, 잎, 과일을 포괄하는 개체, 줄기(trunk): 한 주제에 대한 하위주제를 나타냄(교육 관련일 경우, 하위주제는 School Bullying), 이끼(lichen): 계층구조중 가장 위에 위치한 부분으로, 덩쿨들의 시작점, 가지(branch): 줄기들을 연결함 , 잎(leaf) : 줄기에서 파생된 의견을 나타냄, 과일(fruit): 코멘트의 내용이 원본의 의견과 일치하지 않는 경우, 과일이 생겨남.					식물 : 장미 (꽃잎 하나를 이등분 하여 두개의 값을 나타냄. 하나의 장미가 하나의 제품리뷰의 요약나타냄.)			직물(섬유) - TAPESTRY(평가내용에서 추출되는 극성 정보를 바느질의 패턴으로 나타냄)	구조물(이중으로 된 바퀴-휠: 은행 기관(외부바퀴휠) 및 감성극성(내부바퀴휠)을 나타냄) 구조물2(바퀴살: 공통으로 나타난 평가 키워드를 이어주는 역할을 함)		 건축물 및 구조물(바퀴(링): 댓글을 남긴 사람의 나이 정보, 지리적 정보, 시간 정보를 나타냄) 기하도형(삼각형: 유저들의 극성 분포를 나타내는 틀을 제공함)	건축물 및 구조물(Word Brick: Brand Personality 정도를 평가한 트윗, 리뷰 Topic Block: Factor Bands를 구별하기 위한 경계선.) 기계류: Factor Bands(바퀴휠의 밸트밴드): 의견보유자를 Factor Bands로 나타냄 Comparative BrandWheel:두 브랜드의 Personality Sector 차이 표현 (Comparative Sectors) 기하도형(Personality Sector(Goethe’s Color Wheel): 브랜드 5가지 특성 표현)		기하도형(사각형): 코멘트를 남기는 의견보유자를 나타냄	그림(이모지): 특정 대상에 포함된 사용자들의 감정 정보를 이모지로 표현하고자 함	식품: 피자,파이(각 측면에 대한 논쟁의 극성 비율을 피자 재현물로 시각화함)			기하도형(Colored dot- 토론진행자, 패널들의 의견(발화)을 나타냄), 구조물(Discussion Floor-토론의 주제들을 나타냄)	건축물: 다리(Bridge)- 각 후보자들의 트윗을 나타냄  구조물: 다리의 지지대 - 후보자 트윗에 대한 사용자들의 평가 정보(like)를 나타냄				장식무늬(각 기사에서 다루는 키워드(정당 또는 정치인)가 무엇인지에 따라 서로 다른 장식 무늬로 신문기사를 표현함)		지도: County (리 포스팅 트리에서 키 플레이어가 올리지 않은 Weibo를 나타냄. 영향력 있는 카운티는 검은색 선으로 강조 표시된다. 카운티는 호수와 관련 있고, 국가에 속한다.)  Region (동일한 주제를 가진 카운티는 지도에서 연속된 지역을 형성한다.) Country (하나의 나라는 키플레이어에 의해 형성된 하나의 subtree를 뜻한다.) Continent and Island (지도상에서 크게 연결된 국가들은 대륙을 형성한다. 작고 고립된 나라들은 섬을 형성한다. 서로 다른 나라 간의 연결은 다른 리 포스팅 관계을 표현한다.) 구조물 Route: key player가 자신의 부모 노드의 의견을 따르지 않는 경우 꺾인루트로 연결됨 건축물 Bridge: Key player가 속한 영역의 주제가 부모 노드와 다르다면 다리로 연결됨	기하도형: Hexagon은 비슷한 행동을 지니는 Weibo 사용자나 그룹을 나타냄.  지도: Hexagon이 모여 커뮤니티를 형성하고, 커뮤니티들이 모여 지도가 형성됨.	지도: 사건의 keywords들이 지도를 통해 나타남. City: Keywords(한 이벤트에 관해 적혀진 소셜 미디어 메시지에 나타난 가장 인기 있는 단어) Town: Keywords를 포함하고 있는 메세지 Region: City 와 Town 이 합쳐진것, 하나의 Region은 하나의 City만을 포함함. Contient and Island: 큰 연결성을 가진 Region들은 Contient를 형성하고, 다른 Region과 연결이 없는 경우에는 Island를 만듦. (Region사이의 연결성은 언급된 키워드의 시간에 따른 정보 확산 과정을 반영함.)	지도: 서로 동일하거나 비슷한 Topic을 가진 트윗 그룹을 지도로 표현함			기하도형 Participation-centric view : 선(참가자들의 각 타임라인), 타원(참가자가 같은 이벤트에 참가했음을 표시) 직물(섬유) 감성 밴드(EmotionalBand): 장식무늬(Glyph): 시간별로 트윗 활동을 진행하는 유저를 개인별로/시간별로 시각화하기 위해 Glyph를 사용함 Glyph는 원형노드와 box plot 형태로 구성되는데, 트윗 유저는 원형노드로 표현되고, 트윗 활동은 Box Plot 형태로 표현됨		기하도형: 블럭(리뷰)	그림(이모티콘):감정변화를 나타내기 위해 y축에 감정의 극성을 표현하는 emoticon이 활용됨 기계류(미터기): 각 개인의 감정 상태를 시각화함 장식무늬(Cluster Icon): 리트윗을 한 User group을 나타냄		기하도형: 나선- 트윗 참가자의 시간에따른 활동성을 나타내고자 함		기하도형 - 원(여기서는 node라 표현)이 History diagram에서 URL 쿼리를 나타내기 위해 사용됨, 선(edge)은 해당 Node 사이의 관계를 나타냄.(78 nodes represent URI queries and edges represent the detected relations between corresponding query results ) 장식무늬 - 특정 stance 를 강조하기 위해서 Marker로 표현(형광펜으로 칠한듯 강조해서 나타냄)		기계류(시계): 시간별로 기록되는 사용자의 행동 패턴의 연속성을 나타내기 위해 아날로그 시계의 레이아웃을 재현물로 활용함 기하도형(원): 각 트윗유저의 행동패턴 및 트윗의 의견을 나타냄		소프트웨어(리듬게임 인터페이스)- 시간별로 발생되는 해시테그가 포함된 트윗의 패턴을 리듬게임 인터페이스를 활용하여 표시함, 원근감이 있는 배경 안에 disc가 내려옴 소프트웨어(리더보드리스트)-해시테그활동을 활발히 한 의견보유자를 나타냄 기계류(디스크): 트윗 의견 하나를 요약함 장난감 및 악기(기타의 목 batal 및 기타의 현): 시간의 구간을 나타냄 장난감 및 악기 ballon은 사용자가 포스트를 공유/재공유한 과정 하나를 나타냄 (재공유시, 자신의 감정을 나타낼 수 있음)(Each solid-colored circle represents a tree of reshares) 기하도형 화살표 flow를 나타냄			기하도형(큐브-특정 장소에서 언제 무슨 토픽이 이루어졌는지를 나타내는 가이드라인 역할을 함) 지도+장식무늬(트윗이 발생한 장소를 나타냄)	건축물(두 가지의 블럭:대상에 대해 표현되는 감정의 상태를 나타냄- 감정의 극성 / 감정을 나타내는 주체/ 감정의 양 등)	그림(이모지)- 웹서비스 실험 사용자의 감정 변화를 이모지 아이콘으로 나타냄	장식무늬(tailored density: 등고선의 흐름으로 극성의 종류 및 강도를 나타냄)	기하도형(시공간 터널 패턴: 시간별로 기록되는 감정어휘의 빈도를 Russell의 원형 성격판단 모형을 틀로 표현하고자 함) 건축물 및 구조물(바퀴): sentiwheel: 감정어휘의 분포를 외곽에 위치하고 이를 바퀴로 나타냄		기하도형(링(원): 시간의 흐름에 따라 기록되는 다양한 주제들의 패턴을 나타냄) 기계류(렌즈): 각 토픽과 관련된 자세한 뉴스 장면을 보여줌									건축물 및 구조물 : 지하철 노선도(39개의 성격 대표 어휘를 지하철 역으로 나열), 각 성격 어휘의 사이의 관계와 세분화된 감정어휘의 양상확인이 가능함		건축물 및 구조물 : 바퀴(Wheel)는 각 글 작성자의 음식에 대한 스토리를 나타냄		건축물 및 구조물 : TextWheel (뉴스에 나타난 키워드를 나타냄) 기계류 :Transportation Belt(여러개의 기사가 위치하는 공간으로, 선택된 기사가 달라지면 belt가 회전함), Chain(belt와 wheel을 연결하여 키워드와 기사간의 상관관계를 나타냄) 기하도형: Document Glyph(하나의 기사를 표현)	기하도형(원): 소셜 네트워크속 유저를 나타냄 구조물(시소): 두 유저 간의 감정 관계의 정도를 표현하기 위한 수단으로 사용됨	기하도형(원): 미팅 참가자들을 나타냄 기계류(심전도): 회의가 진행될 때, 수집되는 메시지에 나타나는 감성 정보의 강도를 심전도의 펄스로 나타냄 행동(정치인들의 로비활동 행적을 곤충이 거품 사이를 이동하는 행동으로 표현함)					자연현상: Bubble의 퇴적 (BrandSediment)	자연현상(나무의 성장, 뿌리의 성장): 특정 장면 구간에 수집되는 댓글이 많을수록, 나무의 줄기가 높아지고, 뿌리가 깊어짐	자연현상(폭포수의 낙수): 시간별로 축적되어 퍼져나가는(확산되는) 코멘트의 동향을 나타냄					자연현상(dot의 퇴적, 시간에 따라서 특정 주제를 나타내는 둘레에 의견들이 쌓임)	자연현상: 강의흐름(River flow) - 시간에 따라 축적되는 의견 양의 변화를 나타냄 인공물의 생성: 다리의 건설 - 시간에 따라 축적되는 각 후보자의 의견들을 나타냄	자연현상(나무의 성장과 가지의 분열) - 시간에 따른 키워드의 등장 흐름을 나타낼 때 그룹 간, 그룹 내로 분열하는 키워드의 흐름을 나무의 성장과 가지의 분열로 나타냄	자연현상(2중 나선의 진행(생성))- 시간이 지남에 따라 두 진영을 나타내는 외가닥이 Divergence의 정도에 따라서 2중 나선 형태로 진행이 되면서 smooth curving strand가 생성됨	자연현상(나무의 성장과 가지의 분열)			시공간의 이동 : Root user /Key Player를 중심으로 의견 및 정보의 시간에 따른 확산																									행동(시간에 따라 전자핵이 적절한 극성의 영역으로 이동함)				자연현상(강물의 흐름과, 등고선 색상의 변화: 의견 빈도 변화와 극성의 변화를 시간에 따라 나타내고자 함)		자연현상(강물의 폭 변화/지류의 변화/ 색상변화): 의견의 극성 및 협력과 분열 관계에 따라서 강물의 흐름이 바뀜		자연현상(강물의 폭 변화: 루머 정보의 양에 따라서 달라짐, 혹은 루머에 대한 사람들의 각 평가 성향의 양에 따라서 달라짐)			자연현상(거품의 퇴적: 실시간으로 기록되는 트윗들을 기간에 따라서 퇴적시킴, 최근의 트윗일수록 맨 위에 거품일 위치하고 아래로 갈수록 퇴적되다가 사라짐)	자연현상(지층퇴적: 실시간으로 기록되는 트윗들을 기간에 따라서 퇴적시킴)		자연현상: 덩쿨의 성장(vine growth), 계층구조로 의견이 각 주제가 확산되는 패턴을 나타냄.								시공간의 이동(달력): 달력을 모델로 해서 년도, 날짜, 시간별로 이어지는 메시지의 추이, 빈도 변화를 나타냄 인공물의 생성(바느질 작업):기간별로 나타나는 평가의 극성에 따라 알맞은 바느질 패턴이 나타남	인공물의 생성 및 소멸 (평가 극성의 변화를 내부 휠의 형태를 변화시킴)	자연현상(나뭇잎이 쌓임: 동일 기간 내에 평가가 많이 모일수록 나뭇잎이 쌓이게 됨)														인공물의 생성 및 소멸(시간에 따라 적절한 모양의 장식 무늬 패턴이 기록됨)			인공물의 생성과 소멸 : Tell story of dynamic diffusion(시각화 사용자가 각 확산 단계를 선택하여 볼수 있어 확산 과정의 이해를 가능하게함.)		인공물의 생성 및 소멸(지도의 확장 및 축소): 각 시간별로 기록되는 트윗 그룹의 수에 따라서 지도의 면적이 확장되거나 축소됨					자연현상(거품의 증식): 유저가 남긴 트윗 메시지가 리트윗 활동에 의해서 퍼져나가는 패턴을 표현함	자연현상(꽃의 개화): 특정 유저의 이니셜 포스팅 및 댓글, 반응 등이 나타나는 과정을 꽃의 개화로 표현함. 이니셜 포스팅, 댓글 등이 많아질수록 꽃잎이 여러개로 형성됨, 그리고 response에 따라서 꽃잎 위에 많은 pistil이 생김				자연현상(꽃의 개화): 리트윗의 확산 경로를 꽃이 성장하는 현상으로 은유함								소프트웨어의 작동: 시간에 따라 발생되는 트윗의 분포의 반복, 시작, 소멸, 가속을 나타냄.							인공물의 생성(간트차트의 생성: 각 구간별로 적절한 감정 정보의 흐름을 나타내기 위해 간트차트가 생성됨)		인공물의 생성 및 소멸(시공간 터널의 작동- 시각화에 표현되는 시간이 축적될때마다 시공간을 나타내는 감정어휘 빈도 시각화가 생성됨. 제일 과거의 시공간 터널은 동시에 소멸됨)		인공물의 생성: 링이 시간에 따라 적절한 주제의 색상으로 생성됨														인공물의 생성 및 소멸(시소축적으로 인한 게슈탈트라인형성): 시간이 지남에 따라서 여러개의 시소가 축적되면서 개슈탈트라인을 만들어냄으로써 전체적인 감정의 기울기를 볼 수 있게함"

# %%
Visvar = "댓글의 빈도에 따라서 휠의 명암도가 달라짐	Word Brick의 명암도: 단어가 등장하는 빈도수에 비례하여 표현				각 의견이 가지는 극성의 강도에 따라서 색상의 명암도가 달라짐		밝기: 의견의 빈도수			키워드가 발생된 아이디어 그룹이 달라지면, 키워드를 나타내는 나뭇가지의 색상 명암도가 달라지면서 변화됨											거품의 명암도(Event-centric view): 클라이맥스 스코어에 따라 달라짐	자극(arousal)의 정도  어두운 경우 - 낮은 자극 밝은 경우 - 강한 자극 (The brightness of a band encodes the arousal scale at , where a darker shade implies a lower arousal level.)	Glyph 중심의 명암도: Anomaly Score에 따라 명암도가 달라짐, 진할수록 이상 패턴이 자주 발견되는 유저 Bubble의 명암도: 긍부정의 레벨에 따라서 초록, 노랑, 빨강 노드의 명암도가 달라짐	꽃잎색의 명암도: 오래된 텍스트일수록 명암도가 옅어짐							잎의 명암도: 어두운 색의 잎을 가질 수록 해당되는 키워드가 등장하는 빈도 수가 높아짐을 나타냄								의견에서 추출되는 극성의 강도 따라 세포 안의 테이블 셀의 명암도가 달라짐					장식무늬(TD) 명암도의 변화: 감정의 강도에 따라서 명암도가 달라짐	중간에 감정의 전환이 일어나는 구간에 대해서는 색상의 명도가 달라짐	Coopetition의 강도(power)에 따라서 강물 색상의 명암도가 달라짐								과일의 명암도: 원본 텍스트 데이터에 달린 코멘트의 댓글이 원본의 의견과 불일치하는 정도에 따라 명암도가 결정됨. 		덴드로그램의 명암도: 8개 레벨의 명암차이로 나타내었고, 밝은 색을 가지는 공간일 수록 초기 단계에 연결된 단어로서, 의미적인 유사성이 크다는 것을 의미함.			꽃잎을 구성하고 있는 짝: 같은 색조 안에서 명암도를 달리해 상반되는 의미의 두 값을 표현하고자 함. (ex 긍정-밝은 빨강/부정-어두운 빨강)	Chain의 명암도: 키워드와 텍스트 문서의 관계에 따라 달라짐.		 곤충의 색상: 정당을 나타냄	색상(바느질 패턴의 색상) - 극성에 따라 서로 다른 색상을 사용함	외부 바퀴휠의 색상: 은행 기관별로 다른 색상을 가짐 내부 바퀴휠의 색상: 평가 내용 극성에 따라 다른 색상을 가짐 나뭇잎의 색상- 평가의 극성을 나타냄 (긍정으로갈수록 Green, 부정으로 갈수록 Brown)	댓글을 다는 사람들의 연령대에 따라 링의 색상이 달라짐	Personality Sector의 색상: Sector 구별 위해 색상 사용.  Comparative BrandWheel의 색상: (A브랜드: 파랑, B 브랜드: 노랑) Bubble의 색상: Sector와 같은 색상 사용 괴테휠의 색상: 브랜드 퍼스널리티를 나타냄	뿌리의 색상: 댓글이 가지는 의견의 극성에 따라서 뿌리의 색상이 달라짐 (긍정: 초록/ 중립: 노랑/ 부정: 빨강)	기하도형(사각형)의 색상: 의견보유자의 유형에 따라 색상을 변형함 (키 플레이어(유명인)과 커뮤니티- 분홍색/ 일반인 - 노란색)	이모지의 색상: 각 고유의 감정에 따른 색상 부여를 진행함 (joy:주황, fear: 보라, Anger: 빨강, Disgust: 노랑, Sadness: 회색)	파이, 버블, 나무의 색상: 의견 및 평가 정보의 극성에 따라 달라짐(긍정-초록, 중립-노랑, 부정-빨강)			색상1(의견보유자가 누구인지에 따라 Dot의 색상이 바뀜) 색상2(다양한 색상이 어우러지는 Dot들의 모임-논쟁이 심화됨을 나타냄)	다리의 색상: 각 후보자의 아이덴티티를 나타냄 (힐러리: 분홍/ 트럼프: 파랑)	나뭇가지, 버블의 색상: 아이디어 그룹(의견의 주제)에 따라 나뉘어짐	외가닥의 색상: 시간의 축(X축의 양의방향)에 따라 DNA가 전개될 때, 각 커뮤니티가 가지고 있는 의견의 극성(긍정,부정,중립)에 따라서 외가닥의 색상이 바뀜 (긍정: 초록색, 중립: 노란색, 부정: 빨간색 - 세 가지 색상을 기준으로 긍부정의 정도에 따라서 gradient 색상 효과가 나타남) bar의 색상: keyword의 극성에 따라서 색상이 변경됨 인산염의 색상: 커뮤니티가 남긴 글의 극성에 따라서 인산염의 색상이 달라짐(초록: 긍정, 노랑: 중립, 빨강: 부정)	나뭇가지의 색상: 의견보유자의 아이덴티티 별로 나뭇가지의 색상을 달리함 (Grassroot: 초록/ Media: 노랑/ Political Figures: 빨강)	민주당 관련 뉴스기사는 파란색, 공화당 관련 뉴스기사는 빨간색, 둘 다 언급된 기사라면 회색으로 표현		색상(키워드의 색상): 키워드의 속성을 부정/긍정/중립으로 나눔 색상(노드의 색상): Repost Level에 따라 색상을 분리	색상: - Key Player = Central user 는 주황색 선으로 강조하여 나타냄(Key Player는 다른 유저들에게 리포스팅 된 횟수에 따라 결정됨) - Region의 색은 각 커뮤니티를 분류함.	색상: 사건의 진행 과정을 나타내는 시간 정보를 나타내기 위해 사용됨. (we used color to encode time information)	색상: 군집화된 트윗 유저들이 주로 언급하는 Topic이나 Keyword(의견)에 따라서 색상이 결정됨	취임사에서 드러난 감정마다 깃털의 색을 다르게 하여 나타냄(초록(행복), 파랑(놀람), 핑크(두려움, 역겨움), 빨강(화남), 주황(슬픔))		Participation-centric view: 각 참가자의 타임라인은 다른 색으로 표현됨. (Each participant’s timeline has a different color.) Event-centric view: 색상는 이벤트의 클라이맥스 스코어를 표현함.(The size (and color) of the event bubbles represents the climax score of the event.) 클라이맥스 스코어: 이벤트가 언급된 횟수가 많으면 올라감	밴드의 색상을 변경하여 각 감정 정보를 나타냄 (빨강 - 화남, 보라 - 혐오, 노랑 - 기쁨, 하늘 - 놀람, 주황 - 기대, 초록 - 두려움, 파랑 - 슬픔, 연두 - 신뢰)	Bubble의 색상: 리트윗되는 감성 정보의 극성이 긍정이면 초록, 중립이면 노랑, 부정이면 빨강 꽃잎의 색상: 이니셜 포스팅(magenta), 리플(blue)	블럭의 색상: 초록(긍정), 회색(중립), 주황(부정)	미터기의 색상: 감정의 극성(긍정, 부정, 중립)에 따라서 색상 범위가 나뉘어짐		Seed의 색상: 트윗에 포함된 감성정보의 극성에 따라 색상이 달라짐(긍정: 초록/중립: 노랑/부정: 빨강)		강의 색상: 최근에 진행된 토픽을 초록계열, 과거에 진행된 토픽일 수록 파란계열을 사용함	잎의 색상 (blue 계열: 등장하는 키워드를 나타냄(일반 키워드는 blue로 컬러링),  Purple 계열: 자주나오는 키워드의 문맥 패턴의 시작과 끝을 알리기 위해서 해당 패턴이 시작되는 키워드와 끝나는 키워드를 Purple로 컬러링함)	time line view와 document view에서 같은 색상을 사용하여 사용자의 인식도를 향상 시킴. (Overall, the main benefit of this approach is that it allows of using the same color hues for observers across the timeline and document views that helps to preserve the users’ mental map.) - 색상은 TreeColors package를 통해 생성된 색상을 사용하였음 Marker의 색상 Certainty(초록), Uncertainty(파랑), Joy(주황), Anger(빨강)		Circle의 색상: 의견이 수집된 기간에 따라서 circle의 색상이 달라짐(주중, 주말에 따라 다름)		disc의 색상: 해시테그의 종류에 따라서 색상이 달라짐		가장 위에 위치하고 있는 ballon/Tree(가장 먼저 공유를 시작한 유저)는 pastel 색상을 사용하여 표현됨 극성의 종류에 따라서 빨강에서 파랑의의 범위를 가지는 테이블 셀(부정적 의견일수록 빨강, 긍정일수록 파랑)	극성의 이동이 긍정에서 부정이면 파랑, 부정에서 긍정이면 주황	강의 색상: 트윗이 발생된 장소에 따라 달라짐	감정의 극성에 따라 강의 색 및 블록의 색이 결정됨 (unpleasant: 빨강, 중립: 회색, pleasant: 파랑)	이모지의 색상- 감정의 종류(극성)에 따라서 색상이 달라짐 간트차트의 색상- 감정의 종류(극성)에 따라서 색상이 달라짐	장식무늬의 색상: 감정의 극성이 긍정일경우 초록색 계열, 부정일 경우 붉은색 계열을 사용함	각 감정의 종류 및 강도에 따라서 색상이 정해짐	Coopetition의 극성에 따라 강물의 색상이 달라짐 (긍정: green, 부정: orange)	강물의 색상: 각 뉴스 주제에 따라서 8가지의 강의 색상이 나타남 링의 색상: 동일한 색상 적용 강의 색상(뉴스 기사의 토픽/루머에 대한 사람들의 평가 성향의 종류(질책, 무시, 퍼뜨림) 따라서 강의 색상이 달라짐)				토큰별로 거품의 색상을 달리함		잎의 색상: 잎의 색상을 다르게 변화함. 하지만 각 케이스마다 색이 변화하는 대상은 다르게 나타남. 주제가 'School Bullying' 인 경우, 글 작성자가 작성한 내용의 극성에 따라 색이 달라짐. 		성격 어휘의 색상: 161개의 어휘를 39개의 그룹으로 분류하였으며, 각 그룹에 속하는 단어가 가지고 있는 의미와 연결하여 색을 표현하였음.  (ex. 열정적인 -> 빨간색, 차분한 -> 파란색)  MBTI 성격 유형별 색상: MBTI의 16개 유형을 나타내는 각 노선들은 서로 다른 색을 가지고 있으며, 복잡한 단어들 사이의 관계를 각 노선에 따라 한 눈에 쉽게 볼 수 있게 함. 		바퀴의 한 면의 색상: 사용자가 탐색하고자 하는 카테고리를 선택했을때, 해당 카테고리에 포함되는 면은 초록색으로, 포함되지 않는 면은 빨간색으로 나타남. 스토리를 하나 선택했을 경우에는 보라색으로 표현됨. 	꽃잎의 색: 각 꽃잎을 구성하고 있는 두개의 짝은 공통적인 색조를 가짐.(ex. 긍정과 부정-빨강/협력과 경쟁-하늘)	Chain의 색 : 키워드와 텍스트 문서의 관계에 따라 달라짐.감정의 극성에 따라 Chain의 색이 결정됨 Document Glyph 의 색: 기사에서 언급된 키워드의 수(어두울수록 언급된 수가 많음) Document 와 Wheel 연결선의 색: 키워드의 극성에 따라 달라짐. 	노드의 색상: 각 노드의 감정 강도의 중심값에 대해서 중심값보다 높으면 Red계열, 중심값보다 낮으면 Blue계열, 중심값이면 Grey 계열	기하도형의 색상: 회의 참가자의 아이덴티티에 따라 원의 색상이 결정됨, 또는 회의 참가자가 갖고 있는 감성정보의 극성에 따라서 원의 색상이 달라지는 경우도 있음 버블의 크기: 로비가 많이 연루된 기관일 수록 버블의 크기가 커짐 (비교에 쓰임)		장기간에 걸쳐서 의견이 모아지면 바퀴휠 부분의 면적(size)이 넓어지게 됨. 수집 기간에 따라서 면적이 좌우됨		댓글이 축적되는 정도에 따라서 링의 크기가 달라짐	Personality Sector의 크기: 브랜드 특성 점수에 비례 Bubble의 크기: 5가지 Sector의 값에 따라 결정.	높이: 수집되는 댓글 양이 많을수록 나무가 높이자람, 뿌리도 깊어짐	높이: 수집되는 댓글이 최근이 될 수록 폭포의 단차 높이가 높아짐		파이 및 버블의 크기: 의견 및 평가 빈도수가 높을수록 면적(크기)이 커짐			넓이(주제에 속하는 발화가 많을수록 Discussion Floor의 면적이 넓어짐)	다리의 두께: 트윗의 양	나뭇가지의 넓이: 해당되는 키워드의 언급 빈도 수에 따라서 가지의 폭이 넓어짐. 버블의 크기: 아이디어 그룹(의견의 주제)에 포함되는 키워드가 많을 수록 버블의 크기가 커짐	핵염기쌍을 이루는 bar의 크기(Size): 등장하는 키워드의 빈도에 따라서 핵염기쌍(event box)안에 포함된 bar의 크기가 달라짐 인산염의 크기: 비슷한 의견을 남긴 user group의 규모가 클수록 인산염의 크기가 커짐	넓이: 특정 기간에 특정 집단에서 대선과 관련된 키워드를 많이 언급할 수록 가지의 굵기가 굵어짐/ 특히 논쟁과 대선이 주제가 되는 구간에는 나뭇가지의 굵기가 굵게 표현됨			크기: 지역(region)의 크기 넓이: 링크(link)의 넓이	크기:  - hexagon의 크기는 Weibo 사용자가 포스트한 Weibo의 숫자를 나타냄. - Region의 크기는 커뮤니티에 속하는 사람의 수를 나타냄 넓이: link의 넓이는 두 커뮤니티간의 리포스팅 수를 나타냄.	City의 크기: Keywords 가 포함된 메시지의 수 Town의 크기: 비슷한 시간대에 메시지가 생성된 경우, 한 Town으로 합쳐짐. 따라서 Town의 크기는 포함된 메시지의 개수를 뜻함.  Region의 크기: 포함하고 있는 City의 위치와 Towns에 따라 변화함.	넓이: 같은 Topic을 공유하고 있는 트윗 유저들의 수가 많을 수록 넓은 면적을 가지는 지도의 영토가 나타남	각 깃털 깃의 길이는 감정의 격렬한 정도를 나타냄. (The length of each barb represents the intensity of the emotion.)		거품의 크기(Event-centric view): 이벤트의 클라이맥스 스코어를 표현함The size (and color) of the event bubbles represents the climax score of the event.) oval의 크기(Participation-centric view): 참가자의 수에 따라 크기가 커짐		Glyph 중심의 크기: Follwer 의 수가 많은 트위터 유저일수록 Glyph 중심의 크기가 커짐	줄기의 높이: 유저의 포스팅 참여 기간이 길 수록 높이가 높아짐						강의 폭: 수집되는 키워드의 빈도가 많을수록 쌓이는 강의 폭이 넓어짐	잎의 크기: 자주 등장하는 키워드 일수록 커짐	Node의 크기는 관련된 URL의 수와 비례 거품의 바깥쪽 원의 크기는 문서에서 검출된 각 stance marker의 수와 비례, 안쪽 원의 크기는 unique marker의 수와 비례함.		Circle의 크기: 각 키워드와 관련된 트윗의 빈도 수에 따라서 circle의 크기가 달라짐				크기: 사용자가 재공유한 수에 따라 ballon의 크기가 달라짐.				감정 텍스트 빈도에 따라서 블록의 두께, 강의 폭이 넓어짐		강의 폭: 특정 시간에 수집되는 트윗의 양이 많을수록 강의 폭이 넓어짐	시공간 터널을 표현하는 파형의 크기: 감정어휘의 빈도에 따라서 면적이 달라짐	강의 폭: 특정 시간에 수집되는 트윗의 양이 많을수록 강의 폭이 넓어짐	강의 폭: 각 시간마다 언급된 토픽의 빈도수에 따라서 폭이 달라짐	강의 폭: 루머의 양, 평가 성향의 양에 따라 폭이 달라짐				tag를 많이 언급한 유저일수록 버블 크기가 커짐		이끼의 넓이: 모든 덩쿨이 포함하고 있는 텍스트의 양에 따라 결정됨.  잎의 크기: 잎에 해당하는 노드가 포함하고 있는 텍스트의 양에 따라 결정됨					꽃잎의 크기: 리뷰에서 관련된 내용의 점수가 높을수록 크기가 크게 나타나고, 낮을수록 작게 표현됨.	Keyword 크기: 키워드 크기는 빈도수를 나타냄. 크기가 크면 빈도수가 높음 Document Glyph 의 높이: 그 날에 작성된 기사들의 평균 길이  Document Glyph 의 넓이: 포함된 기사의 수  Glype(Wheel 안의 선)의 넓이: 키워드 동시 언급수(함께 언급된 수가 많을수록 두께가 두꺼워짐.) Chain의 넓이: 키워드와 텍스트 문서의 관계에 따라 달라짐. 감정의 강도에 따라 넓이가 결정됨. 		 곤충의 모양: 로비횟수가 많다고 평가할수록 곤충의 몸집의 형태가 달라짐 (잘록한 허리가 없어지고 통통해지는 형태)	모양(바느질의 패턴) - 극성에 따라 서로 다른 바느질의 패턴이 나타남										나타내고자 하는 분석 대상에 따라서 천체의 모양이 바뀜. 태양-사람(도널드 트럼프). 초록행성-복합속성(도널드 트럼프와 관련된 복합 속성들) 초록행성의 위성-의견(복합속성에서 자주 발견되는 코멘트의 키워드)			특정 키워드가 두 그룹(공화당 진영, 민주당 진영)에 걸쳐서 나타날 시, 나뭇가지가 분열됨, 반면에 시간이 흐른 후 하나의 그룹에서만 언급이 된다면 나뭇가지가 합쳐짐	융합되는 인산염의 모양: 두 진영의 커뮤니티가 서로 비슷한 극성의 의견을 보일 경우, 인산염 유기물이 서로 융합이 되면서 모양이 변형됨	특정 시간에서 수집된 트윗 텍스트가 서로 다른 Topic에서 동시에 트윗이 될 시에는 나뭇가지가 분열됨	정당, 정치인(대통령 후보, 부통령 후보)에 따라서 장식의 심볼이 달라짐				Region의 모양: 포함하고 있는 City의 위치와 Towns에 따라 변화함.  깃털 전체의 곡선  (연설 전체의 전반적인 긍정성 또는 부정성을 나타냄) 긍정적 - 깃털이 위를 향함 중립적 - 깃털이 중앙에 위치함 부정적 - 깃털이 아래를 향함 전체 깃털의 외형(역대 대통령의 취임식 연설 패턴) 참가자 선의 모양(Participation-centric view): 다른 참가자가 같은 이벤트의 부분을 차지한다면, 라인이 구부러지면서 이벤트로 합쳐짐.(If different participants take part in the same event, the lines are bent towards and joint in this event)	감성밴드의 모양: 감정의 격렬한 정도를 나타냄	Behavier Glyph의 외형모양: 각 유저가 진행하는 트윗 활동 패턴에 따라 그려지는 외곽의 Box plot이 다양화됨. 따라서 서로 다른 모양의 Glyph가 형성됨Z-Glyph의 외형모양: 이상패턴과 관련된 Z-score에 따라서 외곽이 area chart로 이루어진 Glyph가 형성됨	꽃잎의 모양: 이니셜 포스팅, 리플이 많을 수록 여러개의 꽃잎이 달려서 원형에 가까운 꽃 모양이 됨				모양: 오리지널 트윗에서는, 트윗을 남긴 유저의 유형에 따라서 Seed의 모양이 달라짐 (언론사, 유명인: 사각형 / 일반인: 원형)														감정을 나타내는 주체가 누가 우위에 있는지에 따라 블록의 질감(모양)이 달라짐(클라이언트 우새 시 대각선라인, 에이전트 우새 시 dot 패턴, 둘 다 대등하면 플러스패턴)									버블의 모양: 각 트윗을 남긴 유저들의 프로필 이미지를 나타냄											 브랜드 특성의 점수에 따라 Topic Block들이 이동함(예시: 사용자가 B.P 중 하나를 클릭 시 (아래 그림에서는 Ruggedness 클릭) 그와 연관된 Topic Block들이 근접하게 됨) Factor Bands의 위치: Factor Bands가 시계방향으로 기업, 사용자, 직원 순으로 위치 Bubble의 위치: 0~100 사이로 수치화해 위치 표현 (0으로 갈수록 점수가 낮음)	위치: 댓글이 수집되는 구간에만 해당되는 장면을 나타내는 나무/뿌리들이 위치함.					천체의 위치: 사람, 양상, 의견에 따라서 천체의 궤도 위치가 달라짐		여러개의 강과 다리를 위치시킴: 검색한 키워드별로 여러개의 강과 다리를 위치시켜 복합 속성을 이해시킴			각 Topic별로 Relationship Tree를 따로 위치시킴	긍정적인 기사면 윗쪽, 중립이면 가운데, 부정적인 기사면 아랫쪽에 위치함				City의 위치: Region의 중심 Town의 위치: City 주변에 위치함.					x 축 - 시간의 흐름을 나타냄 y 축 - 긍정적/부정적인 감정 	트윗 유저들끼리 비교했을 때, 서로 비슷한 성향을 보이는 유저들끼리는 Triangle grid안에서 가까운 위치에 Glyph를 배치함. 반대로는 멀리 배치함		리뷰에서 언급된 숫자에 따라 위치가 정해짐(위->아래)			리트윗이 활성화되지 않은 오리지널 트윗은 Disc floret 내부에 위치하고, 활성화된 트윗은 외부에 위치함  user group을 나타내는 cluster icon을 실제 지리적 위치(국가)에 맞게 위치시킴			특정 키워드와 연결되는 다른 키워드가 여러 개가 있다면, 그 키워드를 나타내는 잎들은 Vertical한 방향으로 위치함			Circle의 위치: 트윗 활동기간, 행동의 지속시간에 따라 적절한 시간 위치에 Circle이 위치함						블로그의 극성에 따라서 부정의 영역이면 원자핵 모형의 안쪽에 위치, 반대이면 바깥쪽에 위치		비슷한 감정 상태를 나타내는 블록끼리 서로 근접하여 위치함			터널을 구성하는 감정 키워드의 위치: russell's circumplex model에 따라 터널의 감정 키워드가 위치함	트윗 텍스트의 극성에 따라서 부정적 극성의 강의 지류는 아랫쪽에, 긍정적 극성의 지류는 윗쪽에 위치함														Wheel에서 Keyword의 위치: 상호간의 관계에 따라 나타남.  위쪽에서 연결된 선은 부정적, 아래쪽에서 연결된 선은 긍정적인 키워드를 나타냄. 	공화당의 진영에서 등장한 키워드, 민주당의 진영에서 등장한 키워드에 따라서 나뭇가지가 자라는 방향이 결정됨. (공화당: 위/ 민주당: 아래)							River의 방향: River는 source region에서 시작하여 Target region에서 끝남		긍정적인 감정은 깃 위, 부정적인 감정은 깃 아래로 그려짐 깃털 (왼쪽 -> 오른쪽) 시간의 흐름			작은 버블 안에 그 시간대에서 중심이 되는 감정을 화살표에 표시하여 나타냄												Circle이 향하는 방향: 자신이 활동한 시간의 방향에 맞게 Circle의 방향이 정해짐(12시 방향, 4시 방향 등...)				시간에 따른 공유 flow 확인을 용이하게 하기 위해 직선의 방향에서 회전한 부드러운 곡선을 사용함.									링이 시계방향을 따라서 생성: 북쪽에서부터 시계방향으로 링(주제)이 생성됨							방향 : 줄기가 자라는 방향, 이전 줄기와는 반대 방향으로 자라나는 형태를 띔 (자연의 섭리에 따름)							두 유저 중 감정의 강도가 치우치는 방향으로 시소가 기울게 됨	심전도의 방향: 회의 참가자가 주고받은 메시지(감성정보)의 강도가 높을수록 진폭이 지그재그 방향으로 전개됨. 강의 폭: 특정 날짜에 두 후보가 남긴 트윗의 양이 많아질수록 강의 폭이 넓어짐		두 진영의 의견차이가 클수록 두 외가닥의 거리가 멀어짐. 반대로 의견이 서로 동일하면 두 외가닥은 가까워지면서 교차됨.						City 사이의 거리: Keywords 사이의 리포스팅 관계와 연속적인 시간 관계에 따라 결정됨. Town와 City 사이의 거리: 시간 간격을 나타냄. 트윗 유저들을 비교 시, 서로 상반된 Anomalous 패턴을 보이면 Glyph의 거리가 멀어짐													디스크 간 거리: 미래에 발생되는 트윗의 패턴일수록 더 멀고 원근감있게 표현함																							각 잎 사이의 간격을 둬, 짝을 이루는 축끼리의 구별을 가능하게 함.			"

# %%
Vistech =	"3차원 공간 안에서 코멘트의 축적을 계층적으로 나타냄																																	포스팅 패턴의 흐름을 3차원 형태로 원근감있게 표시함			서로 리트윗이 되거나, 관련이 있는 코멘트를 링크로 이어줌, 의견 보유자는 사각형의 노드로 나타냄	특정 대상을 중심노드로 하고, 그 노드에 대해서 관련된 감정(이모지) 및 그 감정을 표현한 의견 보유자들이 노드링크 형태로 연결됨					중요하게 언급된 키워드의 맥락을 요약하기 위해 각 키워드들의 관계를 보여주는 노드 링크 시각화가 제공됨							Node-Link Diagram(노드-링크 다이어그램): 사용자를 Node로 나타내고, 화살표를 이용해 해당 Node가 post한 Weibo의 확산경로를 나타냄 Node(Region)-Link(River)를 통해 source region과 target region의 관계를 제시함.	동일한 Topic에 대해서 트윗 또는 리트윗 활동을 한 유저들을 지도 안에서 노드-링크 다이어그램의 형태로 제시함					상호작용이 이루어진 트윗 유저 노드들을 링크로 연결함								tweet에 나타나는 문맥을 쉽게 파악할 수 있도록 관련있는 키워드들의 구조를 node-link 다이어그램 형식으로 표현함	url 쿼리간의 관계를 보여주기 위해 node-link diagram형태의 시각화를 제공						공유 flow를 보여주기 위해 node-link diagram형태의 시각화를 사용함.	유저가 복합속성(한 제품이 가지고 있는 다양한 속성)에 대해서 의견을 준 부분을 노드 링크 다이어그램 형태로 나타냄				구간별로 나타나는 감정 이모티콘 간의 관계를 노드 다이어그램 형태로 나타냄	각 의견을 가지는 그룹을 노드 링크 다이어그램의 형식으로 표현함										의견을 노드(잎)로, 각 주제에 따른 소 주제를 큰 링크(줄기)로 표현하여 시각화 함. 								각 기관을 뜻하는 버블이 로비한 정치인의 수(연루된 정치인의 수)에 따라서 버블 면적이 커짐					Bubble Chart: BrandSediment 상에서 브랜드 하나를 버블(노드)로 표현				각 측면의 분포를 나타내기 위해 버블 차트를 사용함			발화 내용이 길수록 버블의 크기가 커짐, 각 발화자의 발언들을 버블차트의 형태로 나타냄		아이디어 그룹 안에 포함된 키워드의 양에 따라서 버블의 면적을 달리하여 시각화를 진행함											Event-centric view에서 클라이맥스 스코어에 따라 거품의 크기가 달라짐		특정 유저의 트윗을 리트윗한 유저들의 증식(Propagation) 패턴을 나타내기 위해 버블차트를 사용									문서의 양에 따라 버블의 크기가 달라지는 버블차트를 사용함		각 행동 및 사건과 관련된 키워드가 담긴 트윗의 빈도 수에 따라서 Circle의 면적이 달라지는 시각화를 버블 차트로 표현				사용자가 재공유한 데이터의 양의 차이를 보여주기 위해 Bubble chart에서 착안한 Ballon을 시각화에 사용함.														특정 토큰(테그)를 많이 언급한 유저일수록 버블의 크기를 달리하여 시각화함										댓글을 단 사람들의 연령 정보를 링 위에 스택형태의 면적 차트를 배치시킴																							Anomalous 패턴을 시간에 따라 나타내기 위해 z-score를 기반으로 한 Area chart를 제시함							키워드 데이터의 양을 stack graph 형태로 나타냄								시간에 따른 데이터의 양을 나타내기 위해 면적차트을 사용함.					각 채널(video, audio, eye tracking etc) 별로 수집되는 감정정보의 총량을 나타냄	의견을 가지는 그룹을 계층적 형태로 나타내는 방법으로써 스텍 형태의 그래프를 사용함			여러 주제를 가진 뉴스 토픽들이 스택 형태의 그래프를 나타내면서 강의 시각화와 조화를 이룸					의견의 양 비교를 위해 각 버블의 형태를 면적 차트로 나타냄	시간에 따라 이모티콘과 함께 기록되는 라인그래프는 감정의 빈도를 나타냄						시간 데이터를 나타내기 위해 기존의 선 플롯을 사용함. uVSATuses a standard line plot representation for time-series data				대상 트윗의 빈도를 라인플롯으로 나타냄						시간에 따라 감정 상태의 극성 변화를 라인플롯으로 나타냄																	각 장미 아래에는 포함하고 있는 문서의 수를 보여준다. 이를 통해 그룹크기에 대한 영향력을 비교할 수 있음. 			각 정당에서 수집된 키워드의 빈도수를 box plot으로 나타내고, 버블 안에 제시함	주어진 사건에 대한 양을 box plot으로 나타냄					Box Plot(상자 플롯): Repost한 시간에 따라 축적되는 Weibo의 양을 시각화 함. Event-centric view에서는 각 이벤트를 나타냄		Behavior glyph에서 각 유저의 트윗 활동의 빈도를 나타내기 위해 Box Plot을 사용																		시간에 따른 트윗의 총량 변화를 막대 그래프로 나타냄	각 구간별로 모아진 감정 텍스트(테그)의 양을 막대 그래프로 나타냄			각 시간별로 수집되는 감정어휘의 총량을 막대그래프로 나타냄						오랜 시간 퇴적된 버블은 상자플롯으로 변화함	오랜 시간 퇴적된 버블은 상자플롯으로 변화함	 동일한 키워드에 대해서 각 후보가 얼마만큼의 비중으로 이야기했는 지를 비교할 수 있도록 파이차트로 표현함																							노드 안에는 파이 차트와 비슷하게연관된 관찰자들과 관련된 양적 정보가 표시됨. (Nodes are represented by glyphs similar to pie charts (although only qualitative information about relevant observers is used))						Google+ 포스트에 사용된 언어의 분배를 나타내기 위해 파이차트를 사용함.		Radar Chart(레이더 차트): 각 커뮤니티의 행동 특징을 시각화함. 		대상이 가지는 측면의 계층을 나타내기 위해 나무 형태 및 선버스트 형태로 변형된 Treemap 시각화를 제시함																																																			성격 유형과 관련된 어휘들을 나타내기 위해 트리맵과 같은 공간적 계층구조를 사용하였고 이를 통해 효율적인 공간이용이 가능함.						사람들의 리뷰 내용의 상세 키워드 및 표현을 텍스트 클라우드 형태로 시각화함		각 구간별로 수집되는 댓글의 모음을 텍스트 클라우드 형태로 제공함			파이 안에 주요한 논쟁 패턴 키워드를 텍스트 클라우드 형태로 시각화함				언급된 키워드의 빈도 수에 따라 텍스트의 크기를 달리하여 시각화, 중요한 키워드를 요약하여 보여줌	의원들의 트윗 아이디, 의원들이 남기는 키워드 등이 텍스트 클라우드로 시각화됨	특정 시간에 언급되는 커뮤니티의 주요 키워드를 텍스트 클라우드로 보여줌				선택된 weibo 에서 주목되는 Keywords 를 보여줌			트윗 유저들이 남긴 의견 중, 탐색에 도움이 될 수 있는 주요 키워드를 텍스트로 나타냄					트윗에서 언급된 주요 키워드를 시각화함		리뷰 안에 있는 Keyword를 텍스트 클라우스 형태로 보여줌	EMOCLOUD의 형태는 tag cloud를 기반으로 함: 감정 정보 및 키워드를 시각화함										대상 트윗의 주요 키워드를 텍스트 클라우드로 표시함					각 지역, 특정 시간에 발생한 트윗의 주요 토픽을 텍스트 클라우드 형태로 나타냄		각 감정 구간에서 언급된 감정 어휘, 주요 어휘들을 텍스트 클라우드로 나타냄			각 구간의 자세한 트윗 텍스트 및 키워드는 텍스트 클라우드 형태로 시각화됨		루머의 주요 키워드 및, 루머를 퍼뜨리는 주체들의 정보를 텍스트 클라우드로 나타냄														특정 기간에 수집된 메시지의 주요 키워드를 텍스트 클라우드로 나타냄 Temporal view에서 각 Keyword가 포함된 메시지의 수를 색상의 변화를 통해 나타냄(색상이 진할수록 - 많이 언급)						시간에 따른 트윗 활동 패턴(anomalous 패턴)을 히트맵으로 제시함																각 양상에 대한 극성 정보를 히트맵으로 나타냄																							달력 안에서 회의 참가자 수, 메시지 수에 따라서 각 날짜 영역에 히트맵을 표시함 서로 비슷한 극성의 댓글을 단 사람들을 산점도로 분포시킴																																											웹서비스에서 사용자의 시선이동을 산점도 형태로 나타냄/ 각 산점도의 색상에는 감정 정보가 포함됨																			각 유저들의 유사도 패턴을 MDS 분포맵으로 나타냄																			MDS 상에서 유사한 감정 키워드들을 군집하여 분포시킴								시간에 따른 로비 패턴을 제시	기간에 따른 은행 평가 극성의 추이를 시각화로 나타냄	기간에 따른 은행 평가 극성의 추이를 시각화로 나타냄	기간에 따른 은행 평가 극성의 추이를 시각화로 나타냄	시간에 따라 축적되는 댓글 패턴을 시각화함		시간별로 축적되는 댓글의 패턴을 시각화로 나타냄	코멘트의 축적을 기간별로 나타내고자 함		시간별로 수집되는 논쟁 패턴을 파악하고자 함			시간에 따라 축적되는 발화의 패턴을 시각화		시간에 따른 키워드의 등장 흐름/ 연속성을 나뭇가지의 성장, 버블 등으로 제시	대선 토론 진행 시간에 따라 기록되는 두 커뮤니티의 의견 차이를 dna 이중나선 시각화로 제시함	시간에 따라 각 주제별로, 세가지의 집단이 남긴 키워드의 흐름, 논쟁패턴을 시각화함	시간별로 수집되는 각 주제의 뉴스기사들을 시각화함		time line 뷰에서 각 Key Player에 따라 리포스팅의 시간적 패턴을 시각화함	시간별로 수집되는 웨이보 데이터를 시각화함	시간 데이터를 기반으로 overview를 나타내어 사용자가 한 이벤트에 관해 대략적인 내용을 파악 할수 있게 함.	특정 키워드가 시간에 따라 어떤 빈도로 나타나는 지를 제시, 시간에 따라 변화하는 dynamic graph layout을 제시함					시간에 따른 Anomalous 패턴을 히트맵, glyph 재현물 등으로 나타냄	시간에 따른 이니셜포스팅-댓글의 패턴을 꽃을 은유하여 시각화함				시간에따른 리트윗 확산을 보여줌		시간에 따라 등장하는 topic의 추이, 대상 사건에 대한 트윗의 언급 빈도를 시각화를 통해 보여줌		시간에 따른 Keywords의 트렌드를 보여줌		각 기간별 트윗에서 기록되는 행동 패턴을 시각화로 파악하고자 함		시간별 수집되는 해시테그 분포를 시각화함		시간 데이터를 기반으로 시간대별 공유/재공유의 양을 시각화함.		시간에 따른 블로그 포스팅 감성 정보의 극성 변화를 시각화함	시간에 따른 트윗의 패턴을 나타냄	시간에 따른 감정 극성, 빈도의 패턴을 나타냄	시간에 따라 기록되는 감정의 변화를 시각화함	시간에 따라 변화하는 감정의 극성 및 트윗의 양을 표현하고자 타임라인을 기반으로 한 생키다이어그램 + 등고선 패턴 시각화를 제시함	구간별로 수집되는 감정어휘의 빈도 추이를 시각화하고자 함	시간별로 전개되는 Coopetition의 흐름을 시각화하고자 함	시간별로 나타나는 뉴스 토픽의 흐름을 시각화하고자 함	시간별로 수집되는 루머 정보의 빈도를 시각화하고자 함													감정 극성의 기울기 변화를 시간에 따라 축적시키는 시각화를 제안함	메시지의 흐름을 기간별로 나타내어 시각화함/ 메시지의 추이를 파악할 수 있음 리트윗이 이루어지는 지역을 표현하기 위해 지구의 모양을 가져와 해당 지리적 위치를 기반으로 user group 아이콘을 위치시킴													트윗이 발생한 실제 도시를 위치로 나타냄"

# %%
word_tokens = word_tokenize(example) 
stop_words=stop_words.split( ) 
result = [] 
for w in word_tokens: 
    if w not in stop_words: 
        result.append(w) 

print(word_tokens,\n) 
print(result)
# Out:
#   File "C:\Users\hm000\AppData\Local\Temp/ipykernel_25064/3633326439.py", line 8
#     print(word_tokens,\n)
#                          ^
# SyntaxError: unexpected character after line continuation character
